# %%
import pandas as pd
df=pd.read_csv("heart (1).csv")
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# Check for the null values 

df.isna().apply(pd.value_counts)
# Out:
#        age  sex   cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  \
# False  303  303  303     303   303  303      303       303   303      303
#
#        slp  caa  thall  output
# False  303  303    303     303

# %%
#Info about the data shape of data, type of individual columns
df.info()
#unexpected result but i do not know what the true result
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
import matplotlib.pyplot as plt
plt.boxplot(df["age"])
plt.figure(figsize= (20,15))
plt.subplot(3,3,1)
plt.hist(df["age"], color='lightblue', edgecolor = 'black')
plt.show()
plt.show()

# %%
#box plot for sex	
plt.boxplot(df["sex"])
plt.figure(figsize= (20,15))
plt.subplot(3,3,1)
plt.hist(df["sex"], color='lightblue', edgecolor = 'black')
plt.show()
plt.show()

# %%
#Chest Pain type
plt.boxplot(df["cp"])
plt.figure(figsize= (20,15))
plt.subplot(3,3,1)
plt.hist(df["cp"], color='lightblue', edgecolor = 'black')
plt.show()
plt.show()

# %%
#trtbps	 resting blood pressure (in mm Hg)
plt.boxplot(df["trtbps"])
plt.figure(figsize= (20,15))
plt.subplot(3,3,1)
plt.hist(df["trtbps"], color='lightblue', edgecolor = 'black')
plt.show()

# %%
isnull_number = []
for i in df.columns:
    x = df[i].isnull().sum()
    isnull_number.append(x)

pd.DataFrame(isnull_number, index = df.columns, columns = ['Total Missing Values'])
# Out:
#           Total Missing Values
# age                          0
# sex                          0
# cp                           0
# trtbps                       0
# chol                         0
# fbs                          0
# restecg                      0
# thalachh                     0
# exng                         0
# oldpeak                      0
# slp                          0
# caa                          0
# thall                        0
# output                       0

# %%
# Count how many unique value there are in each column

unique_number = []
for i in df.columns:
    x = df[i].nunique()
    unique_number.append(x)

pd.DataFrame(unique_number, index = df.columns, columns = ['Total Unique Values'])
# Out:
#           Total Unique Values
# age                        41
# sex                         2
# cp                          4
# trtbps                     49
# chol                      152
# fbs                         2
# restecg                     3
# thalachh                   91
# exng                        2
# oldpeak                    40
# slp                         3
# caa                         5
# thall                       4
# output                      2

# %%
# Visualization of the numerical columns in loop code

title_font = {'family' : 'arial', 'color' : 'black', 'weight' : 'bold', 'size' : 15}
axis_font = {'family' : 'arial', 'color' : 'darkblue', 'weight' : 'bold', 'size' : 13}

for i, z in list(zip(numeric_var, numeric_axis_name)):
    plt.figure(figsize = (8, 6), dpi = 80)
    sns.distplot(df[i], hist_kws = dict(linewidth = 1, edgecolor = 'k'), bins = 20)
    
    plt.title(i, fontdict = title_font)
    plt.xlabel(z, fontdict = axis_font)
    plt.ylabel('Density', fontdict = axis_font)
    
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 6>()
#       3 title_font = {'family' : 'arial', 'color' : 'black', 'weight' : 'bold', 'size' : 15}
#       4 axis_font = {'family' : 'arial', 'color' : 'darkblue', 'weight' : 'bold', 'size' : 13}
# ----> 6 for i, z in list(zip(numeric_var, numeric_axis_name)):
#       7     plt.figure(figsize = (8, 6), dpi = 80)
#       8     sns.distplot(df[i], hist_kws = dict(linewidth = 1, edgecolor = 'k'), bins = 20)
#
# NameError: name 'numeric_var' is not defined

# %%
# Visualization of the categorical columns in loop code

title_font = {'family' : 'arial', 'color' : 'darkred', 'weight' : 'bold', 'size' : 15}
axis_font = {'family' : 'arial', 'color' : 'darkblue', 'weight' : 'bold', 'size' : 13}

for i, z in list(zip(categoric_var, categoric_axis_name)):
    fig, ax = plt.subplots(figsize=(8, 6))
    
    observation_values = list(df[i].value_counts().index) # loop of the index of the categorical number
    total_observation_values = list(df[i].value_counts()) # loop of the value of the categorical number
    
    ax.pie(total_observation_values, labels=observation_values, autopct = '%1.1f%%', startangle = 110, labeldistance = 1.1)
    ax.axis('equal')
    
    plt.title((i + '(' + z + ')'), fontdict = title_font)
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 6>()
#       3 title_font = {'family' : 'arial', 'color' : 'darkred', 'weight' : 'bold', 'size' : 15}
#       4 axis_font = {'family' : 'arial', 'color' : 'darkblue', 'weight' : 'bold', 'size' : 13}
# ----> 6 for i, z in list(zip(categoric_var, categoric_axis_name)):
#       7     fig, ax = plt.subplots(figsize=(8, 6))
#       9     observation_values = list(df[i].value_counts().index) # loop of the index of the categorical number
#
# NameError: name 'categoric_var' is not defined
